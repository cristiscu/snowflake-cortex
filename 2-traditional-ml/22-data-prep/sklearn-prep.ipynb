# %% [markdown]
# Connect to Snowflake w/ the Python Connector and SNOWSQL config file data

# %%
# see https://github.com/Snowflake-Labs/sfguide-snowpark-scikit-learn/blob/main/3_snowpark_end_to_end_ml.ipynb
import os, configparser
parser = configparser.ConfigParser()
parser.read(os.path.join(os.path.expanduser('~'), ".snowsql/config"))
section = "connections.test_conn"
pars = {
    "account": parser.get(section, "accountname"),
    "user": parser.get(section, "username"),
    "password": parser.get(section, "password"),
    "database": parser.get(section, "database"),
    "schema": parser.get(section, "schema")}

from snowflake.snowpark import Session
session = Session.builder.configs(pars).create()
print(session.sql('select current_warehouse(), current_database(), current_schema()').collect())
# Out:
# [Row(CURRENT_WAREHOUSE()='COMPUTE_WH', CURRENT_DATABASE()='TEST', CURRENT_SCHEMA()='PUBLIC')]

# %% [markdown]
# Get 10% sample data from the HOUSING table, and separate MEDIAN_HOWSE_VALUE

# %%
df = session.table("HOUSING").sample(frac=0.10).to_pandas()
df.shape

X = df.loc[:, df.columns != 'MEDIAN_HOUSE_VALUE']
y = df['MEDIAN_HOUSE_VALUE']
X
# Out:
#       LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  \
# 0       -122.26     37.85                52.0       2491.0           474.0
# 1       -122.28     37.85                49.0       1130.0           244.0
# 2       -122.26     37.83                51.0        936.0           311.0
# 3       -122.26     37.84                49.0        713.0           202.0
# 4       -122.29     37.82                49.0        135.0            29.0
# ...         ...       ...                 ...          ...             ...
# 2077    -121.56     39.16                35.0       2157.0           441.0
# 2078    -121.57     39.13                30.0        442.0           103.0
# 2079    -121.56     39.10                28.0       2130.0           484.0
# 2080    -121.48     39.10                19.0       2043.0           421.0
# 2081    -121.40     39.33                15.0       2655.0           493.0
#
#       POPULATION  HOUSEHOLDS  MEDIAN_INCOME OCEAN_PROXIMITY
# 0         1098.0       468.0         3.0750        NEAR BAY
# 1          607.0       239.0         2.4597        NEAR BAY
# 2          517.0       249.0         1.2852        NEAR BAY
# 3          462.0       189.0         1.0250        NEAR BAY
# 4           86.0        23.0         6.1183        NEAR BAY
# ...          ...         ...            ...             ...
# 2077      1009.0       409.0         1.5827          INLAND
# 2078       413.0        88.0         1.5694          INLAND
# 2079      1195.0       439.0         1.3631          INLAND
# 2080      1018.0       390.0         2.5952          INLAND
# 2081      1200.0       432.0         3.5179          INLAND
#
# [2082 rows x 9 columns]

# %% [markdown]
# Perform data preprocessing in a transformation pipeline

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

COL_NAMES = ['OCEAN_PROXIMITY',
    'LONGITUDE', 'LATITUDE', 'HOUSING_MEDIAN_AGE', 'TOTAL_ROOMS',
    'TOTAL_BEDROOMS', 'POPULATION', 'HOUSEHOLDS', 'MEDIAN_INCOME']
pipeline = ColumnTransformer([(
        "num",
        Pipeline([
            ('imputer', SimpleImputer(strategy="median")),
            ('std_scaler', StandardScaler())]),
        COL_NAMES[1:]
    ), (
        "cat",
        Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
        COL_NAMES[0:0]
    )])
ret = pipeline.fit_transform(X, y)

# %% [markdown]
# Check changes on numeric features

# %%
import pandas as pd
df2 = pd.DataFrame(df, index=df.index, columns=COL_NAMES[1:])
df2.head(10)
# Out:
#    LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  \
# 0    -122.26     37.85                52.0       2491.0           474.0
# 1    -122.28     37.85                49.0       1130.0           244.0
# 2    -122.26     37.83                51.0        936.0           311.0
# 3    -122.26     37.84                49.0        713.0           202.0
# 4    -122.29     37.82                49.0        135.0            29.0
# 5    -122.30     37.81                52.0        572.0           109.0
# 6    -122.28     37.81                36.0       2914.0           562.0
# 7    -122.29     37.81                23.0       1745.0           374.0
# 8    -122.25     37.82                28.0       3337.0           855.0
# 9    -122.25     37.82                52.0       1424.0           289.0
#
#    POPULATION  HOUSEHOLDS  MEDIAN_INCOME
# 0      1098.0       468.0         3.0750
# 1       607.0       239.0         2.4597
# 2       517.0       249.0         1.2852
# 3       462.0       189.0         1.0250
# 4        86.0        23.0         6.1183
# 5       274.0        82.0         1.8516
# 6      1236.0       509.0         2.4464
# 7      1054.0       325.0         0.8026
# 8      1520.0       802.0         3.9063
# 9       550.0       253.0         5.0917
