# %%
df_1 = _deepnote_execute_sql('SELECT date, name, wind, temp\nFROM TEST.PUBLIC.WEATHER\nwhere name in (\'BUFFALO NIAGARA INTERNATIONAL\', \'ROCHESTER\')', 'SQL_FEA06DD5_1D89_40FC_A35C_C78DC3939C52', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_1
# Out:
#             date                           name  wind  temp
# 0     2022-05-12                      ROCHESTER  13.9  39.9
# 1     2022-05-12  BUFFALO NIAGARA INTERNATIONAL   9.1  38.6
# 2     2022-05-11                      ROCHESTER   8.9  41.4
# 3     2022-05-11  BUFFALO NIAGARA INTERNATIONAL   6.2  41.8
# 4     2022-05-10                      ROCHESTER   8.9  41.2
# ...          ...                            ...   ...   ...
# 2919  2018-01-03                      ROCHESTER  14.2  34.8
# 2920  2018-01-02  BUFFALO NIAGARA INTERNATIONAL  11.5  28.8
# 2921  2018-01-02                      ROCHESTER   8.7  30.1
# 2922  2018-01-01  BUFFALO NIAGARA INTERNATIONAL  12.9  30.5
# 2923  2018-01-01                      ROCHESTER   9.8  33.1
#
# [2924 rows x 4 columns]

# %%
import pandas as pd
import numpy as np

station_list = [
    'BUFFALO NIAGARA INTERNATIONAL',
    'ROCHESTER',
    'SYRACUSE HANCOCK INTERNATIONA',
    'ALBANY INTERNATIONAL AIRPORT',
    'CENTRAL PARK']

# %%
df_2 = _deepnote_execute_sql('SELECT date, name, wind, temp\nFROM TEST.PUBLIC.WEATHER\nWHERE name in {{ station_list | inclause}}', 'SQL_FEA06DD5_1D89_40FC_A35C_C78DC3939C52', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_2
# Out:
#             date                           name  wind  temp
# 0     2022-05-12                      ROCHESTER  13.9  39.9
# 1     2022-05-12  BUFFALO NIAGARA INTERNATIONAL   9.1  38.6
# 2     2022-05-12                   CENTRAL PARK   5.9  46.1
# 3     2022-05-11                      ROCHESTER   8.9  41.4
# 4     2022-05-11                   CENTRAL PARK   4.8  53.9
# ...          ...                            ...   ...   ...
# 4513  2018-01-02                   CENTRAL PARK   6.0  35.8
# 4514  2018-01-02                      ROCHESTER   8.7  30.1
# 4515  2018-01-01  BUFFALO NIAGARA INTERNATIONAL  12.9  30.5
# 4516  2018-01-01                   CENTRAL PARK   6.5  40.4
# 4517  2018-01-01                      ROCHESTER   9.8  33.1
#
# [4518 rows x 4 columns]

# %%
DeepnoteChart(df_2, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"trail","color":"#2266D3","tooltip":true},"encoding":{"x":{"sort":null,"type":"nominal","field":"date","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"temp","scale":{"type":"linear","zero":false},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"}}},{"mark":{"size":100,"type":"point","opacity":0,"tooltip":true},"encoding":{"x":{"sort":null,"type":"nominal","field":"date","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"temp","scale":{"type":"linear","zero":false},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{}}""")

# %%
DeepnoteChart(df_2, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"temp","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"y":{"sort":{"order":"descending","encoding":"x"},"type":"nominal","field":"name","scale":{"type":"linear"}},"color":{"sort":null,"type":"nominal","field":"name","scale":{"scheme":"deepnote10"}}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{}}""")

# %%
bin_size = 17

# %%
station = 'BUFFALO NIAGARA INTERNATIONAL'

# %%
df_3 = _deepnote_execute_sql('select count(1) / (select count(1) from test.PUBLIC.WEATHER\n    where name = {{ station }}) percentage_of_results,\n    floor (temp / {{ bin_size | sqlsafe }}) * {{ bin_size | sqlsafe }} bin\nfrom test.PUBLIC.WEATHER\nwhere name = {{ station }}\ngroup by bin\norder by bin', 'SQL_FEA06DD5_1D89_40FC_A35C_C78DC3939C52', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_3
# Out:
#    percentage_of_results   bin
# 0               0.000627 -17.0
# 1               0.037014   0.0
# 2               0.212673  17.0
# 3               0.300502  34.0
# 4               0.229611  51.0
# 5               0.219573  68.0

# %%
DeepnoteChart(df_3, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"area","color":"#2266D3","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"bin","scale":{"type":"linear"},"stack":"zero","format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"y":{"sort":null,"type":"quantitative","field":"percentage_of_results","scale":{"type":"linear"},"stack":"zero","format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{}}""")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d484fe38-42a8-4384-b4ff-2fb9f72b1cac' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
