# %%
from snowflake.snowpark import Session
from snowflake.ml.utils.connection_params import SnowflakeLoginOptions

session = Session.builder.configs(SnowflakeLoginOptions("test_conn")).create()
query = "SELECT *, IFF(CLASS='g', 1.0, 0.0) AS LABEL FROM Telescope"
df = session.sql(query).drop("CLASS")
train_data, test_data = df.random_split(weights=[0.9, 0.1], seed=0)
df.show()
# Out:
# SnowflakeLoginOptions() is in private preview since 0.2.0. Do not use it in production.
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[1], line 6
#       4 session = Session.builder.configs(SnowflakeLoginOptions("test_conn")).create()
#       5 query = "SELECT *, IFF(CLASS='g', 1.0, 0.0) AS LABEL FROM Gamma_Telescope"
# ----> 6 df = session.sql(query).drop("CLASS")
#       7 train_data, test_data = df.random_split(weights=[0.9, 0.1], seed=0)
#       8 df.show()
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\telemetry.py:184, in df_api_usage.<locals>.wrap(*args, **kwargs)
#     182 @functools.wraps(func)
#     183 def wrap(*args, **kwargs):
# --> 184     r = func(*args, **kwargs)
#     185     plan = r._select_statement or r._plan
#     186     # Some DataFrame APIs call other DataFrame APIs, so we need to remove the extra call
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\dataframe.py:1196, in DataFrame.drop(self, *cols)
#    1193         raise SnowparkClientExceptionMessages.DF_CANNOT_DROP_COLUMN_NAME(str(c))
#    1195 normalized_names = {quote_name(n) for n in names}
# -> 1196 existing_names = [attr.name for attr in self._output]
#    1197 keep_col_names = [c for c in existing_names if c not in normalized_names]
#    1198 if not keep_col_names:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\functools.py:969, in cached_property.__get__(self, instance, owner)
#     967 val = cache.get(self.attrname, _NOT_FOUND)
#     968 if val is _NOT_FOUND:
# --> 969     val = self.func(instance)
#     970     try:
#     971         cache[self.attrname] = val
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\dataframe.py:3955, in DataFrame._output(self)
#    3952 @cached_property
#    3953 def _output(self) -> List[Attribute]:
#    3954     return (
# -> 3955         self._select_statement.column_states.projection
#    3956         if self._select_statement
#    3957         else self._plan.output
#    3958     )
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:477, in SelectStatement.column_states(self)
#     475 if self._column_states is None:
#     476     if not self.projection and not self.has_clause:
# --> 477         self.column_states = self.from_.column_states
#     478     else:
#     479         super().column_states  # will assign value to self._column_states
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:270, in Selectable.column_states(self)
#     265 """A dictionary that contains the column states of a query.
#     266 Refer to class ColumnStateDict.
#     267 """
#     268 if self._column_states is None:
#     269     self._column_states = initiate_column_states(
# --> 270         self.snowflake_plan.attributes,
#     271         self.analyzer,
#     272         self.df_aliased_col_name_to_real_col_name,
#     273     )
#     274 return self._column_states
#
# File ~\AppData\Local\Programs\Python\Python39\lib\functools.py:969, in cached_property.__get__(self, instance, owner)
#     967 val = cache.get(self.attrname, _NOT_FOUND)
#     968 if val is _NOT_FOUND:
# --> 969     val = self.func(instance)
#     970     try:
#     971         cache[self.attrname] = val
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:315, in SnowflakePlan.attributes(self)
#     313 @cached_property
#     314 def attributes(self) -> List[Attribute]:
# --> 315     output = analyze_attributes(self.schema_query, self.session)
#     316     # No simplifier case relies on this schema_query change to update SHOW TABLES to a nested sql friendly query.
#     317     if not self.schema_query or not self.session.sql_simplifier_enabled:
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\schema_utils.py:91, in analyze_attributes(sql, session)
#      88     session._run_query(sql)
#      89     return convert_result_meta_to_attribute(session._conn._cursor.description)
# ---> 91 return session._get_result_attributes(sql)
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\session.py:2030, in Session._get_result_attributes(self, query)
#    2029 def _get_result_attributes(self, query: str) -> List[Attribute]:
# -> 2030     return self._conn.get_result_attributes(query)
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:185, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     181     else:
#     182         ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     183             e
#     184         )
# --> 185         raise ne.with_traceback(tb) from None
#     186 else:
#     187     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     188         e
#     189     )
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:121, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     119 def wrap(*args, **kwargs):
#     120     try:
# --> 121         return func(*args, **kwargs)
#     122     except snowflake.connector.errors.ProgrammingError as e:
#     123         query = getattr(e, "query", None)
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:233, in ServerConnection.get_result_attributes(self, query)
#     231 @SnowflakePlan.Decorator.wrap_exception
#     232 def get_result_attributes(self, query: str) -> List[Attribute]:
# --> 233     return convert_result_meta_to_attribute(run_new_describe(self._cursor, query))
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\snowpark\_internal\analyzer\schema_utils.py:144, in run_new_describe(cursor, query)
#     139 # ResultMetadataV2 may not currently be a type, depending on the connector
#     140 # version, so the argument types are pyright ignored
#     142 if hasattr(cursor, "_describe_internal"):
#     143     # Pyright does not perform narrowing here
# --> 144     return cursor._describe_internal(query)  # pyright: ignore
#     145 else:
#     146     return cursor.describe(query)
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\connector\cursor.py:1176, in SnowflakeCursor._describe_internal(self, *args, **kwargs)
#    1165 """Obtain the schema of the result without executing the query.
#    1166
#    1167 This function takes the same arguments as execute, please refer to that function
#    (...)
#    1173     The schema of the result, in the new result metadata format.
#    1174 """
#    1175 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# -> 1176 self.execute(*args, **kwargs)
#    1177 return self._description
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\connector\cursor.py:1136, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1132     is_integrity_error = (
#    1133         code == "100072"
#    1134     )  # NULL result in a non-nullable column
#    1135     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1136     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1137 return self
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\connector\errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\connector\errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     343 if cursor is not None:
#     344     cursor.messages.append((error_class, error_value))
# --> 345     cursor.errorhandler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
#
# File c:\Projects\snowflake-cortex\venv\lib\site-packages\snowflake\connector\errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01b38850-0002-4b09-0000-005b3f076071: 000904 (42000): SQL compilation error: error line 1 at position 14
# invalid identifier 'CLASS'
