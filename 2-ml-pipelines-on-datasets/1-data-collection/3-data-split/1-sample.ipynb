# %%
import pandas as pd
import random

# %% [markdown]
# Skip first 3 rows and read only 2 columns and 3 rows from a local CSV file

# %%
df  = pd.read_csv("../../../.spool/housing.csv",
    usecols=['longitude', 'latitude'],
    nrows=3,
    skiprows=[1, 2, 3])
df
# Out:
#    longitude  latitude
# 0    -122.25     37.85
# 1    -122.25     37.85
# 2    -122.25     37.85

# %% [markdown]
# Import 10% random rows of a local CSV file

# %%
df = pd.read_csv("..\..\..\.spool\housing.csv",
    skiprows=lambda i: i > 0 and random.random() > 0.10)
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.22     37.86                21.0       7099.0          1106.0
# 1       -122.25     37.84                52.0       2535.0           489.0
# 2       -122.28     37.85                41.0        535.0           123.0
# 3       -122.26     37.84                49.0        713.0           202.0
# 4       -122.28     37.82                52.0        945.0           243.0
# ...         ...       ...                 ...          ...             ...
# 2099    -121.92     38.57                10.0       1320.0           246.0
# 2100    -121.57     39.16                21.0       1872.0           302.0
# 2101    -121.59     39.10                24.0       1107.0           261.0
# 2102    -121.54     39.08                23.0       1076.0           216.0
# 2103    -121.21     39.49                18.0        697.0           150.0
#
#       population  households  median_income  median_house_value  \
# ...
